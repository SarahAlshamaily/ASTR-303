# %%
#Importing required packages

# %pylab nbagg
# %matplotlib inline
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#Introducing required variables

x = np.linspace(0,3,1000)

disk = (-1.676*(x-1)) #Bn for disk galaxy is 1.676

exponential = (-7.676*((x**0.25)-1)) #Bn for exponential galaxy is 7.676

#Plotting

plt.figure(figsize=(8,8))
plt.title("Natural Log of the Sum of R versus Ratio of R to Reff")
plt.plot(x,disk,label='disk: n=1')
plt.plot(x,exponential,label='exponential: n=4')
plt.grid()
plt.legend()
plt.xlabel('Ratio of R/Reff')
plt.ylabel('Natural Log of Sum of R')
# Out:
# Text(0, 0.5, 'Natural Log of Sum of R')
